# %% [markdown]
# **Quiz1**
#
# Import ไฟล์ vgsales เช็คข้อมูลเบื้องต้น

# %%
# !wget https://raw.githubusercontent.com/deen666/Homework_DataCamp2/master/PROJECT%20I%20%E2%80%93%20Capstone/vgsales.csv

# %%
# !ls
# Out:
# sample_data  vgsales.csv

# %%
#Run this cell first.
import warnings 
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
#Quiz1

#df = pd.read_csv('vgsales.csv') #My Gdrive Local path.
df = pd.read_csv('https://raw.githubusercontent.com/deen666/Homework_DataCamp2/master/PROJECT%20I%20%E2%80%93%20Capstone/vgsales.csv') #or fetch from the URL.
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 11 columns]

# %%
df.info()
#df.info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
#  To check if there are any NA or NaN.

# %%
df.isnull().values.any()
# Out:
# True

# %%
df = df.dropna()
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# **Quiz2**
#
# สุ่มอ่านข้อมูล 10 แถว หัว 5 แถว และท้าย 10 แถว

# %%
#Quiz2
df.sample(10)
#df.sample(10).head(5)   #Head 5 from the 10 samples.
# Out:
#         Rank  ... Global_Sales
# 13066  13068  ...         0.05
# 6515    6517  ...         0.26
# 3584    3586  ...         0.56
# 11940  11942  ...         0.07
# 12449  12451  ...         0.06
# 6082    6084  ...         0.29
# 886      888  ...         1.93
# 11957  11959  ...         0.07
# 9022    9024  ...         0.14
# 12053  12055  ...         0.07
#
# [10 rows x 11 columns]

# %%
df.head(5)
# Out:
#    Rank                      Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 0     1                Wii Sports      Wii  ...      3.77        8.46        82.74
# 1     2         Super Mario Bros.      NES  ...      6.81        0.77        40.24
# 2     3            Mario Kart Wii      Wii  ...      3.79        3.31        35.82
# 3     4         Wii Sports Resort      Wii  ...      3.28        2.96        33.00
# 4     5  Pokemon Red/Pokemon Blue       GB  ...     10.22        1.00        31.37
#
# [5 rows x 11 columns]

# %%
df.tail(10)
# Out:
#         Rank  ... Global_Sales
# 16588  16591  ...         0.01
# 16589  16592  ...         0.01
# 16590  16593  ...         0.01
# 16591  16594  ...         0.01
# 16592  16595  ...         0.01
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [10 rows x 11 columns]

# %% [markdown]
# **Quiz3**
#
# หา Top 10 Platform ยอดฮิต พร้อมระบุจำนวน

# %%
#Quiz3
#df.groupby('Platform').count()
#df.groupby(['Platform']).agg(['count'])
df.groupby(['Platform']).size().sort_values()[::-1].head(10)
# Out:
# Platform
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# dtype: int64

# %%
#Quiz3
df['Platform'].value_counts().head(10)
# Out:
# DS      2131
# PS2     2127
# PS3     1304
# Wii     1290
# X360    1234
# PSP     1197
# PS      1189
# PC       938
# XB       803
# GBA      786
# Name: Platform, dtype: int64

# %% [markdown]
# **Quiz4**
#
# หา Bottom 10 Platform ยอดฮิต พร้อมระบุจำนวน

# %%
#Quiz4
df['Platform'].value_counts().tail(10)
#df['Platform'].value_counts(sort=True)
# Out:
# GB      97
# DC      52
# GEN     27
# NG      12
# WS       6
# SCD      6
# 3DO      3
# TG16     2
# GG       1
# PCFX     1
# Name: Platform, dtype: int64

# %% [markdown]
# **Quiz5**
#
# หา Top 10 Platform ชนิดของเกมส์ยอดฮิต พร้อมระบุจำนวน

# %%
#Quiz5
df['Genre'].value_counts().head(10)
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Name: Genre, dtype: int64

# %%
df['Genre'].value_counts(sort=True)
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %% [markdown]
# **Quiz6**
#
# หา Bottom 10 Platform ชนิดของเกมส์ยอดฮิต พร้อมระบุจำนวน

# %%
#Quiz6
df['Genre'].value_counts().tail(10)
# Out:
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %% [markdown]
# **Quiz7**
#
# หารายละเอียดเกมส์ GTA V ภาคต่างๆ ทั้งหมด

# %%
#Quiz7
#df['Name'].filter(like='Grand Theft Auto')
#df.filter(regex="Grand Theft Auto V")
df[df['Name']=='Grand Theft Auto V']
# Out:
#       Rank                Name Platform  ...  JP_Sales Other_Sales Global_Sales
# 16      17  Grand Theft Auto V      PS3  ...      0.97        4.14        21.40
# 23      24  Grand Theft Auto V     X360  ...      0.06        1.38        16.38
# 44      45  Grand Theft Auto V      PS4  ...      0.36        2.02        11.98
# 197    198  Grand Theft Auto V     XOne  ...      0.00        0.41         5.08
# 1896  1898  Grand Theft Auto V       PC  ...      0.00        0.08         1.08
#
# [5 rows x 11 columns]

# %% [markdown]
# **Quiz8**
#
# หาจำนวนเกมส์ที่มีชื่อซ้ำกันทั้งหมด

# %%
match_cols = [
    'Name'
]

df['duplicate'] = df.duplicated(
    subset = match_cols,
    keep = False
)

#boolean mask for duplicate = True
mask = (df['duplicate']==True)

#subset for repeated rows
df_rep = (df.loc[mask]).copy(deep = True)

df_dup = df_rep.groupby('Name').count()
df_dup['duplicate']
# Out:
# Name
# 007: Quantum of Solace              6
# 007: The World is not Enough        2
# 11eyes: CrossOver                   2
# 18 Wheeler: American Pro Trucker    2
# 187: Ride or Die                    2
#                                    ..
# iCarly                              2
# iCarly 2: iJoin The Click!          2
# nail'd                              2
# pro evolution soccer 2011           6
# uDraw Studio: Instant Artist        2
# Name: duplicate, Length: 2716, dtype: int64

# %%
#Quiz8
print(df[df['Name'].duplicated(keep = False)].sort_values('Name'))
print(df[df['Name'].duplicated(keep = False)]['Name'].nunique())
# Out:
#         Rank                          Name  ... Global_Sales  duplicate
# 4499    4501        007: Quantum of Solace  ...         0.43       True
# 1273    1275        007: Quantum of Solace  ...         1.49       True
# 1739    1741        007: Quantum of Solace  ...         1.16       True
# 14547  14550        007: Quantum of Solace  ...         0.03       True
# 9318    9320        007: Quantum of Solace  ...         0.14       True
# ...      ...                           ...  ...          ...        ...
# 12605  12607     pro evolution soccer 2011  ...         0.06       True
# 3303    3305     pro evolution soccer 2011  ...         0.61       True
# 639      640     pro evolution soccer 2011  ...         2.42       True
# 15523  15526  uDraw Studio: Instant Artist  ...         0.02       True
# 7835    7837  uDraw Studio: Instant Artist  ...         0.19       True
#
# [7682 rows x 12 columns]
# 2716

# %% [markdown]
# **Quiz9**
#
# หาจำนวนเกมส์ที่มีชื่อและ Platform ซ้ำกันทั้งหมด

# %%
#Quiz9

df2 = df[df[['Name','Platform']].duplicated(keep = False)]
df2
# Out:
#         Rank                         Name  ... Other_Sales  Global_Sales
# 603      604                Madden NFL 13  ...        0.22          2.56
# 1173    1175  Need for Speed: Most Wanted  ...        0.15          1.58
# 1530    1532  Need for Speed: Most Wanted  ...        0.10          1.29
# 1715    1717           Sonic the Hedgehog  ...        0.66          1.18
# 4145    4147           Sonic the Hedgehog  ...        0.00          0.48
# 5900    5902  Need for Speed: Most Wanted  ...        0.05          0.30
# 11676  11678  Need for Speed: Most Wanted  ...        0.02          0.08
# 14997  15000  Wii de Asobu: Metroid Prime  ...        0.00          0.02
# 14999  15002  Wii de Asobu: Metroid Prime  ...        0.00          0.02
# 16127  16130                Madden NFL 13  ...        0.00          0.01
#
# [10 rows x 11 columns]

# %% [markdown]
# **Quiz10**
#
# จากข้อ 9 พิจารณาแถวที่ข้อมูลซ้ำแและลบแถวนั้น

# %%
#Quiz10

df2.drop_duplicates(subset=['Name', 'Platform'], keep='last')
# Out:
#         Rank                         Name  ... Other_Sales  Global_Sales
# 1530    1532  Need for Speed: Most Wanted  ...        0.10          1.29
# 4145    4147           Sonic the Hedgehog  ...        0.00          0.48
# 11676  11678  Need for Speed: Most Wanted  ...        0.02          0.08
# 14999  15002  Wii de Asobu: Metroid Prime  ...        0.00          0.02
# 16127  16130                Madden NFL 13  ...        0.00          0.01
#
# [5 rows x 11 columns]

# %% [markdown]
# **Quiz11**
#
# หารายได้ทั้งหมดเกมส์ FIFA 15

# %%
#Quiz11

df[df['Name']=='FIFA 15']['Global_Sales'].sum()
# Out:
# 19.020000000000003

# %% [markdown]
# **Quiz12**
#
# หารายได้ทั้งหมดของเกมส์ GTA V ในญี่ปุ่น

# %%
#Quiz12

df[df['Name']=='Grand Theft Auto V']['JP_Sales'].sum()
# Out:
# 1.3900000000000001

# %% [markdown]
# **Quiz13**
#
# สร้าง DF ที่ให้ index เป็นรายชื่อของเกมส์ที่มีซ้ำ และ Column เป็นจำนวนที่มีซ้ำ ไม่นับที่เป็น Unique

# %%
#Quiz13 

df2 = df['Name'].value_counts()
df2 = pd.DataFrame(df2)
df2 = df2[df2['Name'] > 1]
df2.rename(columns={'Name':'Count'})
# Out:
#                              Count
# Need for Speed: Most Wanted     12
# Madden NFL 07                    9
# FIFA 14                          9
# Ratatouille                      9
# LEGO Marvel Super Heroes         9
# ...                            ...
# CID The Dummy                    2
# Neopets Puzzle Adventure         2
# Destiny: The Collection          2
# ESPN NFL 2K5                     2
# Myst IV: Revelation              2
#
# [2775 rows x 1 columns]

# %% [markdown]
# **Quiz14**
#
# สร้าง DF ที่มี index เป็นชื่อบริษัท และเรียงลำดับตามรายได้รวมจากมากไปน้อย

# %%
#Quiz14

df.groupby('Publisher').sum().sort_values('Global_Sales')[::-1]
# Out:
#                                 Rank       Year  ...  Global_Sales  duplicate
# Publisher                                        ...
# Nintendo                     2714164  1394666.0  ...       1786.56       86.0
# Electronic Arts              7140412  2686562.0  ...       1110.32     1080.0
# Activision                   6368325  1938979.0  ...        727.46      799.0
# Sony Computer Entertainment  4105604  1367034.0  ...        607.50      135.0
# Ubisoft                      6964728  1843194.0  ...        474.72      546.0
# ...                              ...        ...  ...           ...        ...
# Takuyo                         16506     2011.0  ...          0.01        0.0
# Otomate                        16352     2013.0  ...          0.01        0.0
# Epic Games                     16263     2016.0  ...          0.01        0.0
# Inti Creates                   16475     2016.0  ...          0.01        0.0
# ...

# %% [markdown]
# **Quiz15**
#
# จงสร้าง DF ที่บรรจุเกมส์ Series Call of duty ทั้งหมด

# %%
#Quiz15

COD = df[df['Name'].str.contains('Call of Duty')]
COD
# Out:
#         Rank  ... duplicate
# 29        30  ...      True
# 31        32  ...      True
# 33        34  ...      True
# 34        35  ...      True
# 35        36  ...      True
# 36        37  ...      True
# 37        38  ...      True
# 40        41  ...      True
# 55        56  ...      True
# 61        62  ...      True
# 67        68  ...      True
# 70        71  ...      True
# 93        94  ...      True
# 98        99  ...      True
# 101      102  ...      True
# 120      121  ...      True
# 166      167  ...      True
# 193      194  ...      True
# 244      245  ...      True
# 257      258  ...      True
# 349      350  ...      True
# 500      501  ...      True
# 505      506  ...      True
# 550      551  ...      True
# 711      713  ...      True
# 761      763  ...     False
# 841      843  ...      True
# 861      863  ...      True
# 967      969  ...      True
# 999     1001  ...      True
# 1035    1037  ...     False
# 1037    1039  ...      True
# ...

# %% [markdown]
# **Quiz16**
#
# จงหาว่า Call of Duty ภาคใดใน PC มีรายสูงสุดในยุโรป 5 อันดับแรก

# %%
#Quiz16

COD[COD['Platform']=='PC'].sort_values('EU_Sales')[::-1].head(5)
# Out:
#       Rank                            Name  ... Global_Sales  duplicate
# 1769  1771  Call of Duty 4: Modern Warfare  ...         1.15       True
# 1037  1039  Call of Duty: Modern Warfare 3  ...         1.72       True
# 1126  1128         Call of Duty: Black Ops  ...         1.63       True
# 2347  2349  Call of Duty: Modern Warfare 2  ...         0.89       True
# 1217  1219      Call of Duty: Black Ops II  ...         1.53       True
#
# [5 rows x 12 columns]

# %% [markdown]
# **Quiz17**
#
# จงหาว่า Platform ใด มียอดขายรวมสูงสุดในยุโรป

# %%
#Quiz17

df.groupby('Platform').sum().sort_values('EU_Sales')[::-1].head(1)
# Out:
#              Rank       Year  NA_Sales  ...  Other_Sales  Global_Sales  duplicate
# Platform                                ...
# PS3       9027970  2622109.0    392.26  ...       141.93        957.84     1057.0
#
# [1 rows x 8 columns]

# %% [markdown]
# **Quiz18**
#
# จงหาว่าเกมส์ประเภทใดมียอดขายเฉลี่ยสูงสุดในภูมิภาคอื่นๆรอบโลก

# %%
df.groupby('Genre').sum().sort_values('Global_Sales')[::-1].head(1)
# Out:
#             Rank       Year  NA_Sales  ...  Other_Sales  Global_Sales  duplicate
# Genre                                  ...
# Action  26441383  6531731.0    877.83  ...       187.38       1751.18     2021.0
#
# [1 rows x 8 columns]

# %% [markdown]
# **Quiz19**
#
# สร้าง Bar Plot โดยให้แกน X เป็น Platform และ Y เป็นยอดขายทั่วโลก

# %%
#Quiz19

fig = plt.figure(figsize=(22,8))
sns.barplot(x='Platform',y='Global_Sales',data=df)

# %% [markdown]
# **Quiz20**
#
# สร้าง Pie Chart หาส่วนแบ่งทางการตลาดของ 5 บริษัทแรกที่มีรายได้มากที่สุด

# %%
#Quiz20

df2 = df.groupby('Publisher').sum().sort_values('Global_Sales')[::-1].head(5)
fig = px.pie(df2, values='Global_Sales', names=df2.index)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2d5b635a-888e-4b9f-afe2-eb2477628774" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2d5b635a-888e-4b9f-afe2-eb2477628774")) {
#                     Plotly.newPlot(
#                         '2d5b635a-888e-4b9f-afe2-eb2477628774',
# ...

# %% [markdown]
# **Quiz21**
#
# สร้าง Count Plot นับข้อมูลประเภทของเกมส์

# %%
#Quiz21

fig = plt.figure(figsize=(15,6))
sns.countplot(x='Genre',data=df)

# %% [markdown]
# **Quiz22**
#
# สร้าง Bar plot Top 5 รายได้ทั่วโลกของ Call of Duty ภาคต่างๆใน Xbox

# %%
#Quiz22

COD_TOP5 = COD[COD['Platform']=='X360'].head(5)
COD_TOP5
# Out:
#     Rank                            Name  ... Global_Sales  duplicate
# 29    30  Call of Duty: Modern Warfare 3  ...        14.76       True
# 31    32         Call of Duty: Black Ops  ...        14.64       True
# 35    36      Call of Duty: Black Ops II  ...        13.73       True
# 36    37  Call of Duty: Modern Warfare 2  ...        13.51       True
# 61    62            Call of Duty: Ghosts  ...        10.21       True
#
# [5 rows x 12 columns]

# %%
fig = plt.figure(figsize=(15,6))
sns.barplot(x='Name',y='Global_Sales',data=COD_TOP5)

# %% [markdown]
# **Quiz23**
#
# สร้าง Line Graph แสดงรายได้จาก North America จากปีแรกถึงปีสุดท้าย

# %%
df4 = df.groupby('Year').sum()
df4
# Out:
#             Rank  NA_Sales  EU_Sales  ...  Other_Sales  Global_Sales  duplicate
# Year                                  ...
# 1980.0     29826     10.59      0.67  ...         0.12         11.38        5.0
# 1981.0    190488     33.40      1.96  ...         0.32         35.77        4.0
# 1982.0    149186     26.92      1.65  ...         0.31         28.86        6.0
# 1983.0     56759      7.76      0.80  ...         0.14         16.79        4.0
# 1984.0     22911     33.28      2.10  ...         0.70         50.36        4.0
# 1985.0     55505     33.73      4.74  ...         0.92         53.94        3.0
# 1986.0     35986     12.50      2.84  ...         1.93         37.07        3.0
# 1987.0     54701      8.46      1.41  ...         0.20         21.74        2.0
# 1988.0     37181     23.87      6.59  ...         0.99         47.22        7.0
# 1989.0     40156     45.15      8.44  ...         1.50         73.45        7.0
# ...

# %%
#Quiz23

fig = px.line(df4, x=df4.index, y='NA_Sales', title='Sale of NA')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c59eb40f-ff0f-4bc3-907d-11ec269effdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c59eb40f-ff0f-4bc3-907d-11ec269effdc")) {
#                     Plotly.newPlot(
#                         'c59eb40f-ff0f-4bc3-907d-11ec269effdc',
# ...

# %% [markdown]
# **Quiz24**
#
# สร้าง Stripplot โดยให้แกน X เป็น Genre และ แกน Y เป็นรายได้ทั่วโลก

# %%
#Quiz24

fig = plt.figure(figsize=(15,6))
fig = sns.stripplot(x='Genre',y='Global_Sales',data=df)
fig.set(ylim=(0,15))
# Out:
# [(0.0, 15.0)]

# %% [markdown]
# **Quiz25**
#
# สร้าง Distribution Plot ของปี

# %%
#Quiz25

fig = plt.figure(figsize=(15,6))
sns.distplot(df['Year'])

# %% [markdown]
# **Quiz26**
#
# สร้าง Bar Plot แสดงรายได้รวมในญี่ปุ่นรายปี

# %%
#Quiz26

fig = plt.figure(figsize=(15,6))
sns.barplot(x=df4.index,y='JP_Sales',data=df4)
fig.autofmt_xdate()
